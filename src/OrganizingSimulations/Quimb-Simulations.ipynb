# %%
import qutip
import numpy as np
import itertools

import pandas as pd
import sqlite3
import pickle
import time

from numpy import pi, sqrt

# %%
columnsSimulation = (\
    'SimulationUUID', \
    'HamiltonianUUID', \
    'DecoherenceUUID', \
    'InitialConditionUUID', \
    'NumberOfSpins',
    'TimeInitial', \
    'TimeFinal', \
    'NumberOfSteps')

# %%
columnsDecoherence = (\
    'DecoherenceUUID', \
    'DecoherenceType', \
    'GammaPlus', \
    'GammaMinus', \
    'GammaZ')

# %%
dfSpinHalfSizes = pd.DataFrame(data=[(n, 2**n, np.log10(2.0**n), np.log10(2.0**(n/2))) for n in range(2, 56, 2)],
            columns=(r'$n$', r'$2^n$', r'$\log_{10}(2^n)$',  r'$\log_{10}(2^{n/2})$'))

print(dfSpinHalfSizes.to_latex())
# Out:
# \begin{tabular}{lrrrr}
# \toprule
# {} &  \$n\$ &              \$2\textasciicircum n\$ &  \$\textbackslash log\_\{10\}(2\textasciicircum n)\$ &  \$\textbackslash log\_\{10\}(2\textasciicircum \{n/2\})\$ \\
# \midrule
# 0  &    2 &                  4 &           0.60206 &               0.30103 \\
# 1  &    4 &                 16 &           1.20412 &               0.60206 \\
# 2  &    6 &                 64 &           1.80618 &               0.90309 \\
# 3  &    8 &                256 &           2.40824 &               1.20412 \\
# 4  &   10 &               1024 &           3.01030 &               1.50515 \\
# 5  &   12 &               4096 &           3.61236 &               1.80618 \\
# 6  &   14 &              16384 &           4.21442 &               2.10721 \\
# 7  &   16 &              65536 &           4.81648 &               2.40824 \\
# 8  &   18 &             262144 &           5.41854 &               2.70927 \\
# 9  &   20 &            1048576 &           6.02060 &               3.01030 \\
# 10 &   22 &            4194304 &           6.62266 &               3.31133 \\
# 11 &   24 &           16777216 &           7.22472 &               3.61236 \\
# 12 &   26 &           67108864 &           7.82678 &               3.91339 \\
# 13 &   28 &          268435456 &           8.42884 &               4.21442 \\
# 14 &   30 &         1073741824 &           9.03090 &               4.51545 \\
# 15 &   32 &         4294967296 &           9.63296 &               4.81648 \\
# 16 &   34 &        17179869184 &          10.23502 &               5.11751 \\
# 17 &   36 &        68719476736 &          10.83708 &               5.41854 \\
# 18 &   38 &       274877906944 &          11.43914 &               5.71957 \\
# 19 &   40 &      1099511627776 &          12.04120 &               6.02060 \\
# 20 &   42 &      4398046511104 &          12.64326 &               6.32163 \\
# 21 &   44 &     17592186044416 &          13.24532 &               6.62266 \\
# 22 &   46 &     70368744177664 &          13.84738 &               6.92369 \\
# 23 &   48 &    281474976710656 &          14.44944 &               7.22472 \\
# 24 &   50 &   1125899906842624 &          15.05150 &               7.52575 \\
# 25 &   52 &   4503599627370496 &          15.65356 &               7.82678 \\
# 26 &   54 &  18014398509481984 &          16.25562 &               8.12781 \\
# \bottomrule
# \end{tabular}

# %%
dfSpinHalfSizes
# Out:
#     $n$              $2^n$  $\log_{10}(2^n)$  $\log_{10}(2^{n/2})$
# 0     2                  4           0.60206               0.30103
# 1     4                 16           1.20412               0.60206
# 2     6                 64           1.80618               0.90309
# 3     8                256           2.40824               1.20412
# 4    10               1024           3.01030               1.50515
# 5    12               4096           3.61236               1.80618
# 6    14              16384           4.21442               2.10721
# 7    16              65536           4.81648               2.40824
# 8    18             262144           5.41854               2.70927
# 9    20            1048576           6.02060               3.01030
# 10   22            4194304           6.62266               3.31133
# 11   24           16777216           7.22472               3.61236
# 12   26           67108864           7.82678               3.91339
# 13   28          268435456           8.42884               4.21442
# 14   30         1073741824           9.03090               4.51545
# 15   32         4294967296           9.63296               4.81648
# 16   34        17179869184          10.23502               5.11751
# 17   36        68719476736          10.83708               5.41854
# 18   38       274877906944          11.43914               5.71957
# 19   40      1099511627776          12.04120               6.02060
# 20   42      4398046511104          12.64326               6.32163
# 21   44     17592186044416          13.24532               6.62266
# 22   46     70368744177664          13.84738               6.92369
# 23   48    281474976710656          14.44944               7.22472
# 24   50   1125899906842624          15.05150               7.52575
# 25   52   4503599627370496          15.65356               7.82678
# 26   54  18014398509481984          16.25562               8.12781

# %%
from numpy import sin, cos, exp
def prepareSpinHalfState (polarAngle, azimuthalAngle):
    '''
    Prepares a pure spin state state given by azimuthal angle
    and polar angle
    '''
    
    zBasisCoefficients = np.asarray([ \
        cos(polarAngle), \
        sin(polarAngle) * exp(azimuthalAngle) \
    ], dtype='complex')
    
    return zBasisCoefficients

# %%
prepareSpinHalfState(pi, 0)
# Out:
# array([-1.0000000e+00+0.j,  1.2246468e-16+0.j])

# %%
import quimb as qu
import quimb.tensor as qtn

# %%
qtn.MPS_product_state([prepareSpinHalfState(pi, 0)] * 54)
# Out:
# <MatrixProductState(tensors=54, indices=107, structure='I{}', nsites=54)>

# %%
qtn.tensor_gen.Tensor(qu.controlled('Z'), inds=('a0', 'a1'))
# Out:
# Tensor(shape=(4, 4), inds=('a0', 'a1'), tags=set())
