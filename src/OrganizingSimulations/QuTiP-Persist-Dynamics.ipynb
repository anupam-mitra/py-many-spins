# %% [markdown]
# # Exploring the possibilities
#
# I want to build a database (SQL) of different simulations.
#
# ## 2 qubit model
# I consider a simple simulation involving two qubits. The Hamiltonian reads
# $$
# H =
# J \left(\sigma_z \otimes \sigma_z\right) +
# B \left(\sigma_x \otimes 1 + 1 \otimes \sigma_x\right)
# $$
# Additionally, there is local decoherence on each qubit given by jump operators $\sqrt{\Gamma} \left(\sigma_- \otimes 1\right)$ and $\sqrt{\Gamma} \left(1 \otimes \sigma_-\right)$. The initial state is $|\uparrow_z\rangle \otimes |\uparrow_z\rangle$.
#
# ## Collective spin model
# I also consider a simple situation involving a collective spin with a linear term and a quadratic term. The Hamiltonian reads
# $$
# H = J S_z^2 + B S_x
# $$
# Additionally, there is collective decoherence given by jump operators $\sqrt{\Gamma} S_-$.

# %% [markdown]
# # Implementation questions
# 1. Consider a few different methods of saving simulation data to a table.
#     1. Put the `qutip.solver.Result` object in the SQL database. I am storing everything from the simulation, I can store the time stamps for the starting and ending times.
#         - Run a simulation.
#         - Convert the `qutip.solver.Result` into `bytes` using `pickle.dumps`.
#         - Save these `bytes` objects as `BLOB` values in a column of an SQL table.
#     2. Put the `qutip.qobj.Qobj` objects representing the state in the SQL database.
#         - Run a simulation.
#         - Extract the states as `qutip.qobj.Qobj`.
#         - Convert the states into `bytes` using `pickle.dumps`.
#         - Save these `bytes` objects as `BLOB` values in a column of an `pandas.DataFrame`
#         - Save the `pandas.DataFrame` to an SQL table
# 2. How close are the density matrices estimated by monte carlo wavefunction or quantum trajectories using `qutip.mcsolve` and solving the master equation using `qutip.mesolve`?

# %%
import qutip
import numpy as np
import itertools

import uuid
import time

import sqlite3
import pandas as pd
import pickle

from numpy import pi, sqrt

# %%
def save_result_blob (string_uuid, hamiltonians, ρ_initial, tlist, jumops, method, db_filename):
    
    # Run the simulation
    timestamp_start = time.time_ns()
    
    if method.lower() == 'me':
        result = qutip.mesolve(hamiltonians, ρ_initial, tlist, jumpops)
    elif method.lower() == 'mc':
        result = qutip.mcsolve(hamiltonians, ρ_initial, tlist, jumpops, ntraj=11)

    timestamp_end = time.time_ns()

    # Convert the `qutip.solver.Result` object to `bytes
    result_bytes = pickle.dumps(result)
    
    simulation_row = (string_uuid, timestamp_start, timestamp_end, result_bytes)
    
    # Save the row to a table of a SQL database
    if db_filename == None:
        return

    conn = sqlite3.connect(db_filename)
    cursor = conn.cursor()
    
    sql_create = '''
        CREATE TABLE IF NOT EXISTS SimulationSavedResults
        (uuid text,
        timestamp_start real,
        timestamp_end real,
        result blob)
    '''
    
    sql_insert = '''
        INSERT INTO SimulationSavedResults
        (uuid, timestamp_start, timestamp_end, result)
        VALUES
        (?, ?, ?, ?)'''
    
    cursor.execute(sql_create)
    cursor.execute(sql_insert, simulation_row)
    
    conn.commit()
    conn.close()

# %%
def save_state_blob (string_uuid, hamiltonians, ρ_initial, tlist, jumops, method, db_filename):
    
    # Run the simulation
    timestamp_start = time.time_ns()
    
    if method.lower() == 'me':
        result = qutip.mesolve(hamiltonians, ρ_initial, tlist, jumpops)
    elif method.lower() == 'mc':
        n_traj = 11
        result = qutip.mcsolve(hamiltonians, ρ_initial, tlist, jumpops, ntraj=n_traj)

    timestamp_end = time.time_ns()

    # Extract the states at different times
    n_steps = len(tlist)

    simulation_result_rows = []
    for s in range(n_steps):
        t = tlist[s]
        if method.lower() == 'me':
            # When solving the master equation, there is one state for each instance
            # of time. Therefore, there is one row for the state at each time.
            state = result.states[s]
            state_bytes = pickle.dumps(state)
            simulation_result_rows += [(string_uuid, t, None, state_bytes)]
        elif method.lower() == 'mc':
            # when using monte carlo wave function, there is one state for each instance
            # time and each trajectory. Therefore, there are multiple rows for the state
            # at each time
            for tr in range(n_traj):
                state = result.states[tr, s]
                state_bytes = pickle.dumps(state)
                simulation_result_rows += [(string_uuid, t, tr, state_bytes)]
                
                
    # Save the row to a table of a SQL database
    
    if db_filename == None:
        return
    
    simulations_df = pd.DataFrame(data=[(string_uuid, timestamp_start, timestamp_end)], columns=('uuid', 'timestamp_start', 'timestamp_end'))
    simulation_results_df = pd.DataFrame(data=simulation_result_rows, columns=('uuid', 'time', 'trajectory_index', 'state'))
    
    conn = sqlite3.connect(db_filename)
    
    simulations_df.to_sql('Simulations', con=conn, if_exists='append')
    simulation_results_df.to_sql('SimulationSavedStates', con=conn, if_exists='append')
    
    conn.commit()
    conn.close()
    
#     sql_create_simulations = '''
#         CREATE TABLE IF NOT EXISTS Simulations
#         (uuid text,
#         timestamp_start real,
#         timestamp_end real)
#     '''

#     sql_create_simulationresults = '''
#         CREATE TABLE IF NOT EXISTS SimulationSavedStates
#         (uuid text,
#         time real,
#         trajectory_index integer,
#         state blob)
#     '''
    
#     sql_insert_simulations = '''
#         INSERT INTO Simulations
#     '''

# %%
Ω = 1
κ = 1
Γ = 1e-2

t_initial = 0
t_final = 8 * 2*pi
n_steps = 128
n_traj = 11

t_list = np.linspace(t_initial, t_final, n_steps)

# %%
uuid_generated = uuid.uuid4() 
string_uuid = str(uuid_generated)

# This is the collective spin model
spin_j = 63/2
ket_initial = qutip.spin_coherent(spin_j, theta=0, phi=0)
hamiltonians = [Ω * qutip.spin_Jx(spin_j), κ * qutip.spin_Jz(spin_j) * qutip.spin_Jz(spin_j)]
jumpops = [sqrt(Γ) * qutip.spin_Jm(spin_j)]

# %%
db_filename = 'Benchmarking.db'

# %%
# %%time
for _ in range(10):
    save_result_blob(string_uuid, hamiltonians, ket_initial, t_list, jumpops, 'mc', db_filename)
# Out:
# 18.2%. Run time:   4.98s. Est. time left: 00:00:00:22
# 27.3%. Run time:   5.11s. Est. time left: 00:00:00:13
# 36.4%. Run time:   5.11s. Est. time left: 00:00:00:08
# 45.5%. Run time:   9.54s. Est. time left: 00:00:00:11
# 54.5%. Run time:   9.58s. Est. time left: 00:00:00:07
# 63.6%. Run time:   9.65s. Est. time left: 00:00:00:05
# 72.7%. Run time:   9.69s. Est. time left: 00:00:00:03
# 81.8%. Run time:  14.27s. Est. time left: 00:00:00:03
# 90.9%. Run time:  14.28s. Est. time left: 00:00:00:01
# 100.0%. Run time:  14.42s. Est. time left: 00:00:00:00
# Total run time:  14.47s
# 18.2%. Run time:   4.59s. Est. time left: 00:00:00:20
# 27.3%. Run time:   4.68s. Est. time left: 00:00:00:12
# 36.4%. Run time:   4.74s. Est. time left: 00:00:00:08
# 45.5%. Run time:   9.42s. Est. time left: 00:00:00:11
# 54.5%. Run time:   9.48s. Est. time left: 00:00:00:07
# 63.6%. Run time:   9.54s. Est. time left: 00:00:00:05
# 72.7%. Run time:   9.71s. Est. time left: 00:00:00:03
# 81.8%. Run time:  13.97s. Est. time left: 00:00:00:03
# 90.9%. Run time:  14.25s. Est. time left: 00:00:00:01
# 100.0%. Run time:  14.29s. Est. time left: 00:00:00:00
# Total run time:  14.38s
# 18.2%. Run time:   4.76s. Est. time left: 00:00:00:21
# 27.3%. Run time:   4.83s. Est. time left: 00:00:00:12
# 36.4%. Run time:   4.96s. Est. time left: 00:00:00:08
# 45.5%. Run time:   9.37s. Est. time left: 00:00:00:11
# 54.5%. Run time:   9.45s. Est. time left: 00:00:00:07
# 63.6%. Run time:   9.56s. Est. time left: 00:00:00:05
# 72.7%. Run time:   9.71s. Est. time left: 00:00:00:03
# 81.8%. Run time:  13.98s. Est. time left: 00:00:00:03
# 90.9%. Run time:  14.15s. Est. time left: 00:00:00:01
# 100.0%. Run time:  14.22s. Est. time left: 00:00:00:00
# Total run time:  14.32s
# 18.2%. Run time:   4.74s. Est. time left: 00:00:00:21
# 27.3%. Run time:   4.80s. Est. time left: 00:00:00:12
# 36.4%. Run time:   4.82s. Est. time left: 00:00:00:08
# 45.5%. Run time:   9.48s. Est. time left: 00:00:00:11
# 54.5%. Run time:   9.51s. Est. time left: 00:00:00:07
# 63.6%. Run time:   9.70s. Est. time left: 00:00:00:05
# 72.7%. Run time:   9.73s. Est. time left: 00:00:00:03
# 81.8%. Run time:  14.06s. Est. time left: 00:00:00:03
# 90.9%. Run time:  14.21s. Est. time left: 00:00:00:01
# 100.0%. Run time:  14.35s. Est. time left: 00:00:00:00
# Total run time:  14.42s
# 18.2%. Run time:   5.02s. Est. time left: 00:00:00:22
# 27.3%. Run time:   5.04s. Est. time left: 00:00:00:13
# 36.4%. Run time:   5.13s. Est. time left: 00:00:00:08
# 45.5%. Run time:   9.73s. Est. time left: 00:00:00:11
# 54.5%. Run time:   9.77s. Est. time left: 00:00:00:08
# 63.6%. Run time:   9.86s. Est. time left: 00:00:00:05
# 72.7%. Run time:  10.15s. Est. time left: 00:00:00:03
# 81.8%. Run time:  14.44s. Est. time left: 00:00:00:03
# 90.9%. Run time:  14.55s. Est. time left: 00:00:00:01
# 100.0%. Run time:  14.80s. Est. time left: 00:00:00:00
# Total run time:  14.86s
# 18.2%. Run time:   5.00s. Est. time left: 00:00:00:22
# 27.3%. Run time:   5.03s. Est. time left: 00:00:00:13
# 36.4%. Run time:   5.26s. Est. time left: 00:00:00:09
# 45.5%. Run time:   9.81s. Est. time left: 00:00:00:11
# 54.5%. Run time:   9.86s. Est. time left: 00:00:00:08
# 63.6%. Run time:   9.94s. Est. time left: 00:00:00:05
# 72.7%. Run time:  10.46s. Est. time left: 00:00:00:03
# 81.8%. Run time:  14.60s. Est. time left: 00:00:00:03
# 90.9%. Run time:  14.64s. Est. time left: 00:00:00:01
# 100.0%. Run time:  14.72s. Est. time left: 00:00:00:00
# Total run time:  14.76s
# 18.2%. Run time:   4.86s. Est. time left: 00:00:00:21
# 27.3%. Run time:   4.89s. Est. time left: 00:00:00:13
# 36.4%. Run time:   4.95s. Est. time left: 00:00:00:08
# 45.5%. Run time:   9.80s. Est. time left: 00:00:00:11
# 54.5%. Run time:   9.82s. Est. time left: 00:00:00:08
# 63.6%. Run time:   9.91s. Est. time left: 00:00:00:05
# 72.7%. Run time:  10.17s. Est. time left: 00:00:00:03
# 81.8%. Run time:  14.47s. Est. time left: 00:00:00:03
# 90.9%. Run time:  14.77s. Est. time left: 00:00:00:01
# 100.0%. Run time:  14.78s. Est. time left: 00:00:00:00
# Total run time:  14.86s
# 18.2%. Run time:   4.68s. Est. time left: 00:00:00:21
# 27.3%. Run time:   4.79s. Est. time left: 00:00:00:12
# 36.4%. Run time:   4.91s. Est. time left: 00:00:00:08
# 45.5%. Run time:   9.56s. Est. time left: 00:00:00:11
# 54.5%. Run time:   9.67s. Est. time left: 00:00:00:08
# 63.6%. Run time:   9.82s. Est. time left: 00:00:00:05
# 72.7%. Run time:   9.86s. Est. time left: 00:00:00:03
# 81.8%. Run time:  14.25s. Est. time left: 00:00:00:03
# 90.9%. Run time:  14.40s. Est. time left: 00:00:00:01
# 100.0%. Run time:  14.55s. Est. time left: 00:00:00:00
# Total run time:  14.60s
# 18.2%. Run time:   4.89s. Est. time left: 00:00:00:22
# 27.3%. Run time:   5.02s. Est. time left: 00:00:00:13
# 36.4%. Run time:   5.02s. Est. time left: 00:00:00:08
# 45.5%. Run time:   9.64s. Est. time left: 00:00:00:11
# 54.5%. Run time:   9.67s. Est. time left: 00:00:00:08
# 63.6%. Run time:  10.03s. Est. time left: 00:00:00:05
# 72.7%. Run time:  10.08s. Est. time left: 00:00:00:03
# 81.8%. Run time:  14.28s. Est. time left: 00:00:00:03
# 90.9%. Run time:  14.41s. Est. time left: 00:00:00:01
# 100.0%. Run time:  14.74s. Est. time left: 00:00:00:00
# Total run time:  14.76s
# 18.2%. Run time:   4.92s. Est. time left: 00:00:00:22
# 27.3%. Run time:   5.02s. Est. time left: 00:00:00:13
# 36.4%. Run time:   5.14s. Est. time left: 00:00:00:09
# 45.5%. Run time:   9.79s. Est. time left: 00:00:00:11
# 54.5%. Run time:   9.80s. Est. time left: 00:00:00:08
# 63.6%. Run time:   9.93s. Est. time left: 00:00:00:05
# 72.7%. Run time:  10.08s. Est. time left: 00:00:00:03
# 81.8%. Run time:  14.46s. Est. time left: 00:00:00:03
# 90.9%. Run time:  14.53s. Est. time left: 00:00:00:01
# 100.0%. Run time:  14.59s. Est. time left: 00:00:00:00
# Total run time:  14.68s
# CPU times: user 743 ms, sys: 333 ms, total: 1.08 s
# Wall time: 2min 27s

# %%
# %%time
for _ in range(10):
    save_result_blob(string_uuid, hamiltonians, ket_initial, t_list, jumpops, 'mc', None)
# Out:
# 18.2%. Run time:   4.92s. Est. time left: 00:00:00:22
# 27.3%. Run time:   4.95s. Est. time left: 00:00:00:13
# 36.4%. Run time:   5.04s. Est. time left: 00:00:00:08
# 45.5%. Run time:   9.78s. Est. time left: 00:00:00:11
# 54.5%. Run time:  10.07s. Est. time left: 00:00:00:08
# 63.6%. Run time:  10.12s. Est. time left: 00:00:00:05
# 72.7%. Run time:  10.33s. Est. time left: 00:00:00:03
# 81.8%. Run time:  14.61s. Est. time left: 00:00:00:03
# 90.9%. Run time:  14.64s. Est. time left: 00:00:00:01
# 100.0%. Run time:  14.81s. Est. time left: 00:00:00:00
# Total run time:  14.88s
# 18.2%. Run time:   4.88s. Est. time left: 00:00:00:21
# 27.3%. Run time:   4.92s. Est. time left: 00:00:00:13
# 36.4%. Run time:   5.10s. Est. time left: 00:00:00:08
# 45.5%. Run time:   9.66s. Est. time left: 00:00:00:11
# 54.5%. Run time:   9.79s. Est. time left: 00:00:00:08
# 63.6%. Run time:   9.91s. Est. time left: 00:00:00:05
# 72.7%. Run time:  10.45s. Est. time left: 00:00:00:03
# 81.8%. Run time:  14.38s. Est. time left: 00:00:00:03
# 90.9%. Run time:  14.43s. Est. time left: 00:00:00:01
# 100.0%. Run time:  14.69s. Est. time left: 00:00:00:00
# Total run time:  14.77s
# 18.2%. Run time:   5.00s. Est. time left: 00:00:00:22
# 27.3%. Run time:   5.11s. Est. time left: 00:00:00:13
# 36.4%. Run time:   5.15s. Est. time left: 00:00:00:09
# 45.5%. Run time:  10.12s. Est. time left: 00:00:00:12
# 54.5%. Run time:  10.13s. Est. time left: 00:00:00:08
# 63.6%. Run time:  10.16s. Est. time left: 00:00:00:05
# 72.7%. Run time:  10.16s. Est. time left: 00:00:00:03
# 81.8%. Run time:  14.64s. Est. time left: 00:00:00:03
# 90.9%. Run time:  14.94s. Est. time left: 00:00:00:01
# 100.0%. Run time:  14.97s. Est. time left: 00:00:00:00
# Total run time:  15.05s
# 18.2%. Run time:   4.77s. Est. time left: 00:00:00:21
# 27.3%. Run time:   4.90s. Est. time left: 00:00:00:13
# 36.4%. Run time:   4.96s. Est. time left: 00:00:00:08
# 45.5%. Run time:   9.83s. Est. time left: 00:00:00:11
# 54.5%. Run time:   9.83s. Est. time left: 00:00:00:08
# 63.6%. Run time:   9.86s. Est. time left: 00:00:00:05
# 72.7%. Run time:   9.93s. Est. time left: 00:00:00:03
# 81.8%. Run time:  14.52s. Est. time left: 00:00:00:03
# 90.9%. Run time:  14.56s. Est. time left: 00:00:00:01
# 100.0%. Run time:  14.86s. Est. time left: 00:00:00:00
# Total run time:  14.87s
# 18.2%. Run time:   5.05s. Est. time left: 00:00:00:22
# 27.3%. Run time:   5.10s. Est. time left: 00:00:00:13
# 36.4%. Run time:   5.14s. Est. time left: 00:00:00:08
# 45.5%. Run time:   9.98s. Est. time left: 00:00:00:11
# 54.5%. Run time:  10.05s. Est. time left: 00:00:00:08
# 63.6%. Run time:  10.11s. Est. time left: 00:00:00:05
# 72.7%. Run time:  10.12s. Est. time left: 00:00:00:03
# 81.8%. Run time:  14.77s. Est. time left: 00:00:00:03
# 90.9%. Run time:  14.78s. Est. time left: 00:00:00:01
# 100.0%. Run time:  14.86s. Est. time left: 00:00:00:00
# Total run time:  14.91s
# 18.2%. Run time:   5.10s. Est. time left: 00:00:00:22
# 27.3%. Run time:   5.12s. Est. time left: 00:00:00:13
# 36.4%. Run time:   5.17s. Est. time left: 00:00:00:09
# 45.5%. Run time:  10.12s. Est. time left: 00:00:00:12
# 54.5%. Run time:  10.17s. Est. time left: 00:00:00:08
# 63.6%. Run time:  10.22s. Est. time left: 00:00:00:05
# 72.7%. Run time:  10.28s. Est. time left: 00:00:00:03
# 81.8%. Run time:  14.71s. Est. time left: 00:00:00:03
# 90.9%. Run time:  14.80s. Est. time left: 00:00:00:01
# 100.0%. Run time:  15.01s. Est. time left: 00:00:00:00
# Total run time:  15.03s
# 18.2%. Run time:   5.00s. Est. time left: 00:00:00:22
# 27.3%. Run time:   5.03s. Est. time left: 00:00:00:13
# 36.4%. Run time:   5.26s. Est. time left: 00:00:00:09
# 45.5%. Run time:   9.97s. Est. time left: 00:00:00:11
# 54.5%. Run time:  10.00s. Est. time left: 00:00:00:08
# 63.6%. Run time:  10.10s. Est. time left: 00:00:00:05
# 72.7%. Run time:  10.33s. Est. time left: 00:00:00:03
# 81.8%. Run time:  14.49s. Est. time left: 00:00:00:03
# 90.9%. Run time:  14.62s. Est. time left: 00:00:00:01
# 100.0%. Run time:  14.75s. Est. time left: 00:00:00:00
# Total run time:  14.80s
# 18.2%. Run time:   4.97s. Est. time left: 00:00:00:22
# 27.3%. Run time:   5.17s. Est. time left: 00:00:00:13
# 36.4%. Run time:   5.26s. Est. time left: 00:00:00:09
# 45.5%. Run time:   9.81s. Est. time left: 00:00:00:11
# 54.5%. Run time:   9.90s. Est. time left: 00:00:00:08
# 63.6%. Run time:  10.29s. Est. time left: 00:00:00:05
# 72.7%. Run time:  10.42s. Est. time left: 00:00:00:03
# 81.8%. Run time:  14.65s. Est. time left: 00:00:00:03
# 90.9%. Run time:  14.80s. Est. time left: 00:00:00:01
# 100.0%. Run time:  15.07s. Est. time left: 00:00:00:00
# Total run time:  15.13s
# 18.2%. Run time:   4.97s. Est. time left: 00:00:00:22
# 27.3%. Run time:   4.98s. Est. time left: 00:00:00:13
# 36.4%. Run time:   5.04s. Est. time left: 00:00:00:08
# 45.5%. Run time:  10.01s. Est. time left: 00:00:00:12
# 54.5%. Run time:  10.11s. Est. time left: 00:00:00:08
# 63.6%. Run time:  10.12s. Est. time left: 00:00:00:05
# 72.7%. Run time:  10.14s. Est. time left: 00:00:00:03
# 81.8%. Run time:  14.62s. Est. time left: 00:00:00:03
# 90.9%. Run time:  14.71s. Est. time left: 00:00:00:01
# 100.0%. Run time:  14.72s. Est. time left: 00:00:00:00
# Total run time:  14.81s
# 18.2%. Run time:   5.05s. Est. time left: 00:00:00:22
# 27.3%. Run time:   5.08s. Est. time left: 00:00:00:13
# 36.4%. Run time:   5.11s. Est. time left: 00:00:00:08
# 45.5%. Run time:   9.88s. Est. time left: 00:00:00:11
# 54.5%. Run time:  10.23s. Est. time left: 00:00:00:08
# 63.6%. Run time:  10.32s. Est. time left: 00:00:00:05
# 72.7%. Run time:  10.33s. Est. time left: 00:00:00:03
# 81.8%. Run time:  14.65s. Est. time left: 00:00:00:03
# 90.9%. Run time:  14.85s. Est. time left: 00:00:00:01
# 100.0%. Run time:  14.94s. Est. time left: 00:00:00:00
# Total run time:  15.02s
# CPU times: user 721 ms, sys: 286 ms, total: 1.01 s
# Wall time: 2min 29s

# %%
# %%time
for _ in range(10):
    save_state_blob(string_uuid, hamiltonians, ket_initial, t_list, jumpops, 'mc', db_filename)
# Out:
# 18.2%. Run time:   5.11s. Est. time left: 00:00:00:22
# 27.3%. Run time:   5.17s. Est. time left: 00:00:00:13
# 36.4%. Run time:   5.28s. Est. time left: 00:00:00:09
# 45.5%. Run time:   9.82s. Est. time left: 00:00:00:11
# 54.5%. Run time:  10.12s. Est. time left: 00:00:00:08
# 63.6%. Run time:  10.29s. Est. time left: 00:00:00:05
# 72.7%. Run time:  10.33s. Est. time left: 00:00:00:03
# 81.8%. Run time:  14.69s. Est. time left: 00:00:00:03
# 90.9%. Run time:  14.79s. Est. time left: 00:00:00:01
# 100.0%. Run time:  15.19s. Est. time left: 00:00:00:00
# Total run time:  15.28s
# 18.2%. Run time:   4.92s. Est. time left: 00:00:00:22
# 27.3%. Run time:   5.00s. Est. time left: 00:00:00:13
# 36.4%. Run time:   5.09s. Est. time left: 00:00:00:08
# 45.5%. Run time:   9.48s. Est. time left: 00:00:00:11
# 54.5%. Run time:   9.76s. Est. time left: 00:00:00:08
# 63.6%. Run time:  10.04s. Est. time left: 00:00:00:05
# 72.7%. Run time:  10.34s. Est. time left: 00:00:00:03
# 81.8%. Run time:  14.28s. Est. time left: 00:00:00:03
# 90.9%. Run time:  14.38s. Est. time left: 00:00:00:01
# 100.0%. Run time:  14.65s. Est. time left: 00:00:00:00
# Total run time:  14.73s
# 18.2%. Run time:   5.02s. Est. time left: 00:00:00:22
# 27.3%. Run time:   5.07s. Est. time left: 00:00:00:13
# 36.4%. Run time:   5.08s. Est. time left: 00:00:00:08
# 45.5%. Run time:   9.84s. Est. time left: 00:00:00:11
# 54.5%. Run time:  10.11s. Est. time left: 00:00:00:08
# 63.6%. Run time:  10.15s. Est. time left: 00:00:00:05
# 72.7%. Run time:  10.23s. Est. time left: 00:00:00:03
# 81.8%. Run time:  14.61s. Est. time left: 00:00:00:03
# 90.9%. Run time:  14.68s. Est. time left: 00:00:00:01
# 100.0%. Run time:  14.79s. Est. time left: 00:00:00:00
# Total run time:  14.86s
# 18.2%. Run time:   5.07s. Est. time left: 00:00:00:22
# 27.3%. Run time:   5.26s. Est. time left: 00:00:00:14
# 36.4%. Run time:   5.47s. Est. time left: 00:00:00:09
# 45.5%. Run time:  10.17s. Est. time left: 00:00:00:12
# 54.5%. Run time:  10.17s. Est. time left: 00:00:00:08
# 63.6%. Run time:  10.31s. Est. time left: 00:00:00:05
# 72.7%. Run time:  10.39s. Est. time left: 00:00:00:03
# 81.8%. Run time:  14.90s. Est. time left: 00:00:00:03
# 90.9%. Run time:  15.00s. Est. time left: 00:00:00:01
# 100.0%. Run time:  15.09s. Est. time left: 00:00:00:00
# Total run time:  15.10s
# 18.2%. Run time:   5.00s. Est. time left: 00:00:00:22
# 27.3%. Run time:   5.07s. Est. time left: 00:00:00:13
# 36.4%. Run time:   5.15s. Est. time left: 00:00:00:09
# 45.5%. Run time:  10.00s. Est. time left: 00:00:00:12
# 54.5%. Run time:  10.03s. Est. time left: 00:00:00:08
# 63.6%. Run time:  10.15s. Est. time left: 00:00:00:05
# 72.7%. Run time:  10.15s. Est. time left: 00:00:00:03
# 81.8%. Run time:  14.57s. Est. time left: 00:00:00:03
# 90.9%. Run time:  14.70s. Est. time left: 00:00:00:01
# 100.0%. Run time:  14.93s. Est. time left: 00:00:00:00
# Total run time:  14.96s
# 18.2%. Run time:   4.99s. Est. time left: 00:00:00:22
# 27.3%. Run time:   5.05s. Est. time left: 00:00:00:13
# 36.4%. Run time:   5.05s. Est. time left: 00:00:00:08
# 45.5%. Run time:   9.82s. Est. time left: 00:00:00:11
# 54.5%. Run time:   9.98s. Est. time left: 00:00:00:08
# 63.6%. Run time:  10.06s. Est. time left: 00:00:00:05
# 72.7%. Run time:  10.07s. Est. time left: 00:00:00:03
# 81.8%. Run time:  14.47s. Est. time left: 00:00:00:03
# 90.9%. Run time:  14.72s. Est. time left: 00:00:00:01
# 100.0%. Run time:  14.96s. Est. time left: 00:00:00:00
# Total run time:  14.97s
# 18.2%. Run time:   4.95s. Est. time left: 00:00:00:22
# 27.3%. Run time:   5.10s. Est. time left: 00:00:00:13
# 36.4%. Run time:   5.33s. Est. time left: 00:00:00:09
# 45.5%. Run time:   9.79s. Est. time left: 00:00:00:11
# 54.5%. Run time:   9.97s. Est. time left: 00:00:00:08
# 63.6%. Run time:  10.01s. Est. time left: 00:00:00:05
# 72.7%. Run time:  10.52s. Est. time left: 00:00:00:03
# 81.8%. Run time:  14.57s. Est. time left: 00:00:00:03
# 90.9%. Run time:  14.58s. Est. time left: 00:00:00:01
# 100.0%. Run time:  14.70s. Est. time left: 00:00:00:00
# Total run time:  14.73s
# 18.2%. Run time:   4.94s. Est. time left: 00:00:00:22
# 27.3%. Run time:   4.96s. Est. time left: 00:00:00:13
# 36.4%. Run time:   5.22s. Est. time left: 00:00:00:09
# 45.5%. Run time:   9.62s. Est. time left: 00:00:00:11
# 54.5%. Run time:  10.04s. Est. time left: 00:00:00:08
# 63.6%. Run time:  10.20s. Est. time left: 00:00:00:05
# 72.7%. Run time:  10.36s. Est. time left: 00:00:00:03
# 81.8%. Run time:  14.39s. Est. time left: 00:00:00:03
# 90.9%. Run time:  15.00s. Est. time left: 00:00:00:01
# 100.0%. Run time:  15.02s. Est. time left: 00:00:00:00
# Total run time:  15.08s
# 18.2%. Run time:   5.02s. Est. time left: 00:00:00:22
# 27.3%. Run time:   5.08s. Est. time left: 00:00:00:13
# 36.4%. Run time:   5.19s. Est. time left: 00:00:00:09
# 45.5%. Run time:   9.97s. Est. time left: 00:00:00:11
# 54.5%. Run time:  10.02s. Est. time left: 00:00:00:08
# 63.6%. Run time:  10.17s. Est. time left: 00:00:00:05
# 72.7%. Run time:  10.51s. Est. time left: 00:00:00:03
# 81.8%. Run time:  14.51s. Est. time left: 00:00:00:03
# 90.9%. Run time:  14.80s. Est. time left: 00:00:00:01
# 100.0%. Run time:  15.01s. Est. time left: 00:00:00:00
# Total run time:  15.05s
# 18.2%. Run time:   4.98s. Est. time left: 00:00:00:22
# 27.3%. Run time:   5.03s. Est. time left: 00:00:00:13
# 36.4%. Run time:   5.13s. Est. time left: 00:00:00:08
# 45.5%. Run time:  10.09s. Est. time left: 00:00:00:12
# 54.5%. Run time:  10.11s. Est. time left: 00:00:00:08
# 63.6%. Run time:  10.16s. Est. time left: 00:00:00:05
# 72.7%. Run time:  10.24s. Est. time left: 00:00:00:03
# 81.8%. Run time:  14.57s. Est. time left: 00:00:00:03
# 90.9%. Run time:  14.85s. Est. time left: 00:00:00:01
# 100.0%. Run time:  14.86s. Est. time left: 00:00:00:00
# Total run time:  14.94s
# CPU times: user 892 ms, sys: 409 ms, total: 1.3 s
# Wall time: 2min 31s

# %%
# %%time
for _ in range(10):
    save_state_blob(string_uuid, hamiltonians, ket_initial, t_list, jumpops, 'mc', None)
# Out:
# 18.2%. Run time:   5.03s. Est. time left: 00:00:00:22
# 27.3%. Run time:   5.12s. Est. time left: 00:00:00:13
# 36.4%. Run time:   5.13s. Est. time left: 00:00:00:08
# 45.5%. Run time:   9.81s. Est. time left: 00:00:00:11
# 54.5%. Run time:  10.01s. Est. time left: 00:00:00:08
# 63.6%. Run time:  10.12s. Est. time left: 00:00:00:05
# 72.7%. Run time:  10.40s. Est. time left: 00:00:00:03
# 81.8%. Run time:  14.55s. Est. time left: 00:00:00:03
# 90.9%. Run time:  14.77s. Est. time left: 00:00:00:01
# 100.0%. Run time:  15.08s. Est. time left: 00:00:00:00
# Total run time:  15.11s
# 18.2%. Run time:   5.00s. Est. time left: 00:00:00:22
# 27.3%. Run time:   5.09s. Est. time left: 00:00:00:13
# 36.4%. Run time:   5.13s. Est. time left: 00:00:00:08
# 45.5%. Run time:   9.96s. Est. time left: 00:00:00:11
# 54.5%. Run time:  10.05s. Est. time left: 00:00:00:08
# 63.6%. Run time:  10.19s. Est. time left: 00:00:00:05
# 72.7%. Run time:  10.48s. Est. time left: 00:00:00:03
# 81.8%. Run time:  14.87s. Est. time left: 00:00:00:03
# 90.9%. Run time:  14.99s. Est. time left: 00:00:00:01
# 100.0%. Run time:  15.03s. Est. time left: 00:00:00:00
# Total run time:  15.09s
# 18.2%. Run time:   4.93s. Est. time left: 00:00:00:22
# 27.3%. Run time:   5.14s. Est. time left: 00:00:00:13
# 36.4%. Run time:   5.14s. Est. time left: 00:00:00:08
# 45.5%. Run time:   9.73s. Est. time left: 00:00:00:11
# 54.5%. Run time:   9.97s. Est. time left: 00:00:00:08
# 63.6%. Run time:  10.05s. Est. time left: 00:00:00:05
# 72.7%. Run time:  10.46s. Est. time left: 00:00:00:03
# 81.8%. Run time:  14.39s. Est. time left: 00:00:00:03
# 90.9%. Run time:  14.59s. Est. time left: 00:00:00:01
# 100.0%. Run time:  14.75s. Est. time left: 00:00:00:00
# Total run time:  14.76s
# 18.2%. Run time:   4.93s. Est. time left: 00:00:00:22
# 27.3%. Run time:   5.02s. Est. time left: 00:00:00:13
# 36.4%. Run time:   5.09s. Est. time left: 00:00:00:08
# 45.5%. Run time:   9.96s. Est. time left: 00:00:00:11
# 54.5%. Run time:   9.98s. Est. time left: 00:00:00:08
# 63.6%. Run time:  10.03s. Est. time left: 00:00:00:05
# 72.7%. Run time:  10.05s. Est. time left: 00:00:00:03
# 81.8%. Run time:  14.60s. Est. time left: 00:00:00:03
# 90.9%. Run time:  14.62s. Est. time left: 00:00:00:01
# 100.0%. Run time:  14.62s. Est. time left: 00:00:00:00
# Total run time:  14.69s
# 18.2%. Run time:   5.04s. Est. time left: 00:00:00:22
# 27.3%. Run time:   5.14s. Est. time left: 00:00:00:13
# 36.4%. Run time:   5.27s. Est. time left: 00:00:00:09
# 45.5%. Run time:  10.02s. Est. time left: 00:00:00:12
# 54.5%. Run time:  10.10s. Est. time left: 00:00:00:08
# 63.6%. Run time:  10.21s. Est. time left: 00:00:00:05
# 72.7%. Run time:  10.29s. Est. time left: 00:00:00:03
# 81.8%. Run time:  14.72s. Est. time left: 00:00:00:03
# 90.9%. Run time:  14.87s. Est. time left: 00:00:00:01
# 100.0%. Run time:  15.10s. Est. time left: 00:00:00:00
# Total run time:  15.15s
# 18.2%. Run time:   5.20s. Est. time left: 00:00:00:23
# 27.3%. Run time:   5.21s. Est. time left: 00:00:00:13
# 36.4%. Run time:   5.51s. Est. time left: 00:00:00:09
# 45.5%. Run time:  10.15s. Est. time left: 00:00:00:12
# 54.5%. Run time:  10.26s. Est. time left: 00:00:00:08
# 63.6%. Run time:  10.36s. Est. time left: 00:00:00:05
# 72.7%. Run time:  10.62s. Est. time left: 00:00:00:03
# 81.8%. Run time:  14.81s. Est. time left: 00:00:00:03
# 90.9%. Run time:  14.96s. Est. time left: 00:00:00:01
# 100.0%. Run time:  15.29s. Est. time left: 00:00:00:00
# Total run time:  15.38s
# 18.2%. Run time:   4.97s. Est. time left: 00:00:00:22
# 27.3%. Run time:   5.17s. Est. time left: 00:00:00:13
# 36.4%. Run time:   5.21s. Est. time left: 00:00:00:09
# 45.5%. Run time:   9.90s. Est. time left: 00:00:00:11
# 54.5%. Run time:  10.10s. Est. time left: 00:00:00:08
# 63.6%. Run time:  10.12s. Est. time left: 00:00:00:05
# 72.7%. Run time:  10.15s. Est. time left: 00:00:00:03
# 81.8%. Run time:  14.79s. Est. time left: 00:00:00:03
# 90.9%. Run time:  14.85s. Est. time left: 00:00:00:01
# 100.0%. Run time:  14.97s. Est. time left: 00:00:00:00
# Total run time:  15.01s
# 18.2%. Run time:   4.90s. Est. time left: 00:00:00:22
# 27.3%. Run time:   5.05s. Est. time left: 00:00:00:13
# 36.4%. Run time:   5.28s. Est. time left: 00:00:00:09
# 45.5%. Run time:   9.87s. Est. time left: 00:00:00:11
# 54.5%. Run time:   9.96s. Est. time left: 00:00:00:08
# 63.6%. Run time:  10.06s. Est. time left: 00:00:00:05
# 72.7%. Run time:  10.52s. Est. time left: 00:00:00:03
# 81.8%. Run time:  14.78s. Est. time left: 00:00:00:03
# 90.9%. Run time:  14.87s. Est. time left: 00:00:00:01
# 100.0%. Run time:  15.09s. Est. time left: 00:00:00:00
# Total run time:  15.13s
# 18.2%. Run time:   5.01s. Est. time left: 00:00:00:22
# 27.3%. Run time:   5.22s. Est. time left: 00:00:00:13
# 36.4%. Run time:   5.26s. Est. time left: 00:00:00:09
# 45.5%. Run time:  10.11s. Est. time left: 00:00:00:12
# 54.5%. Run time:  10.22s. Est. time left: 00:00:00:08
# 63.6%. Run time:  10.23s. Est. time left: 00:00:00:05
# 72.7%. Run time:  10.38s. Est. time left: 00:00:00:03
# 81.8%. Run time:  14.78s. Est. time left: 00:00:00:03
# 90.9%. Run time:  15.12s. Est. time left: 00:00:00:01
# 100.0%. Run time:  15.25s. Est. time left: 00:00:00:00
# Total run time:  15.27s
# 18.2%. Run time:   5.11s. Est. time left: 00:00:00:23
# 27.3%. Run time:   5.19s. Est. time left: 00:00:00:13
# 36.4%. Run time:   5.36s. Est. time left: 00:00:00:09
# 45.5%. Run time:  10.09s. Est. time left: 00:00:00:12
# 54.5%. Run time:  10.11s. Est. time left: 00:00:00:08
# 63.6%. Run time:  10.23s. Est. time left: 00:00:00:05
# 72.7%. Run time:  10.49s. Est. time left: 00:00:00:03
# 81.8%. Run time:  14.99s. Est. time left: 00:00:00:03
# 90.9%. Run time:  15.02s. Est. time left: 00:00:00:01
# 100.0%. Run time:  15.09s. Est. time left: 00:00:00:00
# Total run time:  15.19s
# CPU times: user 786 ms, sys: 279 ms, total: 1.06 s
# Wall time: 2min 31s

# %%
ρ_trajectories_mc = np.empty((n_traj, n_steps), dtype=object)

for tr, st in itertools.product(range(n_traj), range(n_steps)):
     #ρ_estimates_mc[tr, st] = qutip.ket2dm(results_mc.states[tr, st])
    pass
